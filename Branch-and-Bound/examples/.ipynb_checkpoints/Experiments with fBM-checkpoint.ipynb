# %%
import sys
sys.path.insert(0, '../backend')
sys.path.insert(0, '../../data')

# %%
import numpy as np
import time
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

import pybnb
from transformers import *
from fbm import FBM

from generalized_dtw import Warp
from branch_and_bound_warped_pvar import BnBWarping

# %%
dist = 'eucl'

if dist == 'eucl':
    # Euclidean
    d = lambda a, b: (a-b)**2
    f_d = lambda DD, a, b: np.sqrt(DD**2 + d(a, b))
    final_operator = lambda x: np.sqrt(x)

elif dist == 'manh':
    # Manhattan
    d = lambda a, b : np.abs(a-b)
    f_d = lambda DD, a, b: DD + d(a,b)
    final_operator = lambda x: x
    
else:
    # Minkowksi
    d = lambda a, b : np.abs(a-b)
    f_d = lambda DD, a, b: max(DD, d(a,b))
    final_operator = lambda x: x

# %%
fbm_generator = FBM(n=20, hurst=0.3, length=1)
fbm_sample = fbm_generator.fbm()
fbm_sample_smooth = pd.Series(fbm_sample).rolling(window=5).mean()
df = pd.DataFrame([fbm_sample, fbm_sample_smooth], index=['fBM', 'smooth_fBM']).T.dropna()
df.plot(figsize=(12, 10))
plt.show()

# %% [markdown]
# # DTW

# %%
W = Warp(df.fBM.values, df.smooth_fBM.values, d, f_d, final_operator)

# %%
plt.figure(figsize=(12, 10))
W.plot_alignment()

# %%
plt.figure(figsize=(10, 8))
W.plot_lattice()

# %% [markdown]
# # Warped rough p-var distance

# %%
x = AddTime().fit_transform([df.fBM.values])[0]
y = AddTime().fit_transform([df.smooth_fBM.values])[0]

# %%
problem = BnBWarping(x=x, y=y, p=2.1, depth=2, norm='l1', root_node=(0, 0), bc=3, cache_size=1024,
                     plot_2d=True, record_path=False, pvar_dist_mem=None, pvar_mem_org=None, 
                     initial_time=None, use_bound1=True, use_bound2=True, use_bound3=True)

solver = pybnb.Solver()

results = solver.solve(problem, log=None, queue_strategy='depth')

print('warped p-var: {:.2f}'.format(results.objective))
print('wall time: {:.2f} secs \n'.format(results.wall_time))

best_warp = results.best_node.state
print('best_warp: {} \n'.format(best_warp[1:]))
_, optimal_partition = problem.distance(results.best_node.state, optim_partition=True)
problem.plot_alignment([best_warp[k] for k in optimal_partition])
plt.show()
# Out:
# Exception caught: 'BnBWarping' object has no attribute 'pvar_mem_org'
# Attempting to shut down, but this may hang.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-59b6c0ddc975> in <module>
#       5 solver = pybnb.Solver()
#       6
# ----> 7 results = solver.solve(problem, log=None, queue_strategy='depth')
#       8
#       9 print('warped p-var: {:.2f}'.format(results.objective))
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pybnb\solver.py in solve(self, problem, best_objective, best_node, disable_objective_call, absolute_gap, relative_gap, scale_function, queue_tolerance, branch_tolerance, comparison_tolerance, objective_stop, bound_stop, node_limit, time_limit, queue_limit, track_bound, initialize_queue, queue_strategy, log_interval_seconds, log_new_incumbent, log, disable_signal_handlers)
#     933                                       best_node,
#     934                                       disable_objective_call,
# --> 935                                       convergence_checker)
#     936             (results.objective,
#     937              results.best_node,
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pybnb\solver.py in _solve(self, problem, best_objective, best_node, disable_objective_call, convergence_checker)
#     329                 del results_
#     330                 continue
# --> 331             new_bound = _cast_to_float_or_int(problem.bound())
#     332             if convergence_checker.bound_worsened(new_bound,
#     333                                                   working_node.bound):    #pragma:nocover
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pybnb\problem.py in bound(self)
#     357     def bound(self):
#     358         start = self._clock()
# --> 359         tmp = self._problem.bound()
#     360         stop = self._clock()
#     361         self._solve_info._increment_bound_stat(stop-start, 1)
#
# ~\source\repos\crispitagorico\warped-p-variation\Branch-and-Bound\backend\branch_and_bound_warped_pvar.py in bound(self)
#     245             along a partial path based on the best known objective.
#     246         """
# --> 247         return self.compute_bound(self.path)
#     248
#     249     def notify_new_best_node(self, node, current):
#
# ~\source\repos\crispitagorico\warped-p-variation\Branch-and-Bound\backend\branch_and_bound_warped_pvar.py in compute_bound(self, warp)
#     236             b = self.bound2(warp)
#     237             if (b < self.best_node_value) and (self.use_bound3):
# --> 238                 b = (b**self.p + self.bound3(warp)**self.p)**(1./self.p)
#     239
#     240         return b
#
# ~\source\repos\crispitagorico\warped-p-variation\Branch-and-Bound\backend\branch_and_bound_warped_pvar.py in bound3(self, warp)
#     223         i,j = warp[-1] # current position in lattice
#     224
# --> 225         return self.bound3_precomputation(i+self.i0,j+self.j0)
#     226
#     227     def compute_bound(self, warp):
#
# ~\source\repos\crispitagorico\warped-p-variation\Branch-and-Bound\backend\branch_and_bound_warped_pvar.py in bound3_precomputation(self, I, J)
#     211             sub_problem = BnBWarping(x=sub_x, y=sub_y, p=self.p, depth=self.depth, norm=self.norm, root_node=(i,j), bc=1,
#     212                                      record_path=False, plot_2d=self.plot_2d, pvar_dist_mem=self.pvar_dist_mem,
# --> 213                                      pvar_mem_org=self.pvar_mem_org, initial_time=self.initial_time,
#     214                                      use_bound1=self.use_bound1, use_bound2=self.use_bound2, use_bound3=self.use_bound3)
#     215
#
# AttributeError: 'BnBWarping' object has no attribute 'pvar_mem_org'
